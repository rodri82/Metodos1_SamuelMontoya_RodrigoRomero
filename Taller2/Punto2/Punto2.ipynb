# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
V=2
R=2
def funcion(x,y):
    return V*x*(1-((R*R)/((x*x)+(y*y))))

# %%
N=25
x = np.linspace(-4,4,N)
y = np.linspace(-4,4,N)

h=0.001

X,Y = np.meshgrid(x,y)

# %%
def derivativex(f,x,y,h):
    return (f(x+h,y)-f(x-h,y))/(2*h)
def derivativey(f,x,y,h):
    return (f(x,y+h)-f(x,y-h))/(2*h)

# %%
Vx=derivativex(funcion,X,Y,h)
Vy=-derivativey(funcion,X,Y,h)

Vx = Vx.T
Vy = Vy.T

# %%
fig1 = plt.figure(figsize=(5,5))
ax = fig1.add_subplot(1,1,1)
#circulo
angulo=np.linspace(0,2*np.pi,200)
r=2
a=r*np.cos(angulo)
b=r*np.sin(angulo)

for i in range(1,len(x)):
    for j in range(1,len(y)):
        
        ax.quiver(x[i],y[j],Vx[i,j],Vy[i,j],color='r')

#circulo
# Out:
# <img src="data:image/png;base64,..." width="500">
