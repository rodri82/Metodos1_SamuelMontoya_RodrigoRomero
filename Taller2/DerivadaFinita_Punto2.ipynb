# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x: 1/np.sqrt(1+np.exp(-x**2))
h = 0.05

# %%
x = np.linspace(-10,10,int(20/h))
y = f(x)

# %%
def derivative(f,x,h):
    return (f(x+h)-f(x-h))/(2*h)

# %%
df = derivative(f,x,h)

# %%
df_exact = (np.exp(-x**2)*x)/((1+np.exp(-x**2))**(3/2))

# %%
error = abs(df-df_exact)

# %%
fig = plt.figure(figsize=(10,3))
ax1 = fig.add_subplot(1,2,1)
ax1.plot(x, y, color='g', label='f(x)')
ax1.plot(x,df,color='r',label='Derivada numérica')
ax1.legend(loc=0)
ax1.grid(alpha=0.25)
ax2 = fig.add_subplot(1,2,2)
ax2.scatter(x, error,s=1)
ax2.grid(alpha=0.25)
ax2.title.set_text('Error de Estimación')
# Out:
# <img src="data:image/png;base64,..." width="1000.2666666666668">
